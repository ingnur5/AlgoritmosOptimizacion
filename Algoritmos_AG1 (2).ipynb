# %% [markdown]
# #ACTIVIDAD Y RETO
# ##Nur Derly Carpeta Sánchez

# %% [markdown]
# #Algoritmos - Actividad Guiada 1
#
# Nombre: Raul Reyero Diez<br>
# URL: https://colab.research.google.com/drive/1lJqfBFQFbfb39vkg9KlMqWj527tXl9uY?usp=sharing
#
# http:github.com/rauxxxx/Algoritmos..

# %% [markdown]
# ##Torres de Hanoi con Divide y vencerás

# %%
def Torres_Hanoi(N, desde, hasta):
  if N ==1 :
    print("Lleva la ficha " ,desde , " hasta ", hasta )

  else:
    #Torres_Hanoi(N-1, desde, 6-desde-hasta )
    Torres_Hanoi(N-1, desde, 6-desde-hasta )
    print("Lleva la ficha " ,desde , " hasta ", hasta )
    #Torres_Hanoi(N-1,6-desde-hasta, hasta )
    Torres_Hanoi(N-1, 6-desde-hasta  , hasta )


Torres_Hanoi(3, 1 , 3)
# Out:
# Lleva la ficha  1  hasta  3
# Lleva la ficha  1  hasta  2
# Lleva la ficha  3  hasta  2
# Lleva la ficha  1  hasta  3
# Lleva la ficha  2  hasta  1
# Lleva la ficha  2  hasta  3
# Lleva la ficha  1  hasta  3

# %%
#Sucesión_de_Fibonacci
#https://es.wikipedia.org/wiki/Sucesi%C3%B3n_de_Fibonacci
#Calculo del termino n-simo de la suscesión de Fibonacci
def Fibonacci(N:int):
  if N < 2:
    return 1
  else:
    return Fibonacci(N-1)+Fibonacci(N-2)

Fibonacci(5)
# Out:
# 8

# %% [markdown]
# ##Devolución de cambio por técnica voraz

# %%
def cambio_monedas(N, SM):
  SOLUCION = [0]*len(SM)   #SOLUCION = [0,0,0,0,..]
  ValorAcumulado = 0

  for i,valor in enumerate(SM):
    monedas =  (N-ValorAcumulado)//valor
    SOLUCION[i] = monedas
    ValorAcumulado = ValorAcumulado + monedas*valor

    if ValorAcumulado == N:
      return SOLUCION


cambio_monedas(15,[25,10,5,1])
# Out:
# [0, 1, 1, 0]

# %% [markdown]
# ## N-Reinas por técnica de vueta atrás

# %%
def escribe(S):
  n = len(S)
  for x in range(n):
    print("")
    for i in range(n):
      if S[i] == x+1:
        print(" X " , end="")
      else:
        print(" - ", end="")


def es_prometedora(SOLUCION,etapa):
  #print(SOLUCION)
  #Si la solución tiene dos valores iguales no es valida => Dos reinas en la misma fila
  for i in range(etapa+1):
    #print("El valor " + str(SOLUCION[i]) + " está " +  str(SOLUCION.count(SOLUCION[i])) + " veces")
    if SOLUCION.count(SOLUCION[i]) > 1:
      return False

    #Verifica las diagonales
    for j in range(i+1, etapa +1 ):
      #print("Comprobando diagonal de " + str(i) + " y " + str(j))
      if abs(i-j) == abs(SOLUCION[i]-SOLUCION[j]) : return False
  return True



def reinas(N, solucion=[], etapa=0):
  if len(solucion) == 0:
      solucion=[0 for i in range(N)]

  for i in range(1, N+1):
    solucion[etapa] = i

    if es_prometedora(solucion, etapa):
      if etapa == N-1:
        print(solucion)
        #escribe(solucion)
        print()
      else:
        reinas(N, solucion, etapa+1)
    else:
      None

    solucion[etapa] = 0

reinas(8)
# Out:
# [1, 5, 8, 6, 3, 7, 2, 4]
#
# [1, 6, 8, 3, 7, 4, 2, 5]
#
# [1, 7, 4, 6, 8, 2, 5, 3]
#
# [1, 7, 5, 8, 2, 4, 6, 3]
#
# [2, 4, 6, 8, 3, 1, 7, 5]
#
# [2, 5, 7, 1, 3, 8, 6, 4]
#
# [2, 5, 7, 4, 1, 8, 6, 3]
#
# [2, 6, 1, 7, 4, 8, 3, 5]
#
# [2, 6, 8, 3, 1, 4, 7, 5]
#
# [2, 7, 3, 6, 8, 5, 1, 4]
#
# [2, 7, 5, 8, 1, 4, 6, 3]
#
# [2, 8, 6, 1, 3, 5, 7, 4]
#
# [3, 1, 7, 5, 8, 2, 4, 6]
#
# [3, 5, 2, 8, 1, 7, 4, 6]
#
# [3, 5, 2, 8, 6, 4, 7, 1]
#
# [3, 5, 7, 1, 4, 2, 8, 6]
#
# [3, 5, 8, 4, 1, 7, 2, 6]
#
# [3, 6, 2, 5, 8, 1, 7, 4]
#
# [3, 6, 2, 7, 1, 4, 8, 5]
#
# [3, 6, 2, 7, 5, 1, 8, 4]
#
# [3, 6, 4, 1, 8, 5, 7, 2]
#
# [3, 6, 4, 2, 8, 5, 7, 1]
#
# [3, 6, 8, 1, 4, 7, 5, 2]
#
# [3, 6, 8, 1, 5, 7, 2, 4]
#
# [3, 6, 8, 2, 4, 1, 7, 5]
#
# [3, 7, 2, 8, 5, 1, 4, 6]
#
# [3, 7, 2, 8, 6, 4, 1, 5]
#
# [3, 8, 4, 7, 1, 6, 2, 5]
#
# [4, 1, 5, 8, 2, 7, 3, 6]
#
# [4, 1, 5, 8, 6, 3, 7, 2]
#
# [4, 2, 5, 8, 6, 1, 3, 7]
#
# [4, 2, 7, 3, 6, 8, 1, 5]
#
# [4, 2, 7, 3, 6, 8, 5, 1]
#
# [4, 2, 7, 5, 1, 8, 6, 3]
#
# ...

# %% [markdown]
# ## Viaje por el rio. Programación dinámica

# %%
TARIFAS = [
[0,5,4,3,999,999,999],
[999,0,999,2,3,999,11],
[999,999, 0,1,999,4,10],
[999,999,999, 0,5,6,9],
[999,999, 999,999,0,999,4],
[999,999, 999,999,999,0,3],
[999,999,999,999,999,999,0]
]



################################################################
def Precios(TARIFAS):
################################################################
  #Total de Nodos
  N = len(TARIFAS[0])

  #Inicialización de la tabla de precios
  PRECIOS = [ [9999]*N for i in [9999]*N]
  RUTA = [ [""]*N for i in [""]*N]

  for i in range(0,N-1):
    RUTA[i][i] = i             #Para ir de i a i se "pasa por i"
    PRECIOS[i][i] = 0          #Para ir de i a i se se paga 0
    for j in range(i+1, N):
      MIN = TARIFAS[i][j]
      RUTA[i][j] = i

      for k in range(i, j):
        if PRECIOS[i][k] + TARIFAS[k][j] < MIN:
            MIN = min(MIN, PRECIOS[i][k] + TARIFAS[k][j] )
            RUTA[i][j] = k          #Anota que para ir de i a j hay que pasar por k
        PRECIOS[i][j] = MIN

  return PRECIOS,RUTA
################################################################


PRECIOS,RUTA = Precios(TARIFAS)
#print(PRECIOS[0][6])

print("PRECIOS")
for i in range(len(TARIFAS)):
  print(PRECIOS[i])

print("\nRUTA")
for i in range(len(TARIFAS)):
  print(RUTA[i])

#Determinar la ruta con Recursividad
def calcular_ruta(RUTA, desde, hasta):
  if desde == hasta:
    #print("Ir a :" + str(desde))
    return ""
  else:
    return str(calcular_ruta( RUTA, desde, RUTA[desde][hasta])) +  \
                ',' + \
                str(RUTA[desde][hasta] \
              )

print("\nLa ruta es:")
calcular_ruta(RUTA, 0,6)
# Out:
# PRECIOS
# [0, 5, 4, 3, 8, 8, 11]
# [9999, 0, 999, 2, 3, 8, 7]
# [9999, 9999, 0, 1, 6, 4, 7]
# [9999, 9999, 9999, 0, 5, 6, 9]
# [9999, 9999, 9999, 9999, 0, 999, 4]
# [9999, 9999, 9999, 9999, 9999, 0, 3]
# [9999, 9999, 9999, 9999, 9999, 9999, 9999]
#
# RUTA
# [0, 0, 0, 0, 1, 2, 5]
# ['', 1, 1, 1, 1, 3, 4]
# ['', '', 2, 2, 3, 2, 5]
# ['', '', '', 3, 3, 3, 3]
# ['', '', '', '', 4, 4, 4]
# ['', '', '', '', '', 5, 5]
# ['', '', '', '', '', '', '']
#
# La ruta es:
# ',0,2,5'

# %% [markdown]
# # **Encontrar los dos puntos más cercanos**
#
# Dado un conjunto de puntos se trata de encontrar los dos puntos más cercanos <br>
# Guía para aprender:
# Suponer en 1D, o sea, una lista de números: [3403, 4537, 9089, 9746, 7259, ....]
# 1. Primer intento: Fuerza bruta
# Calcular la complejidad.<br>
#  ¿Se puede mejorar?
# 2. Segundo intento: Aplicar Divide y Vencerás
# Calcular la complejidad.<br> ¿Se puede mejorar?
# Extender el algoritmo a 2D: [(1122, 6175), (135, 4076), (7296, 2741), ....]
# Extender el algoritmo a 3D.

# %% [markdown]
# ## 1. Primero en 1D
#
# Si los números están en una sola línea, esto es fácil: los ordeno y miro
# cuáles quedan uno al lado del otro. Ese es el par ganador, no hace falta
# comparar todo contra todo.
#
# ¿Por qué esto funciona? Porque si dos números no quedan de vecinos después
# de ordenar, es porque hay otro número metido entre ellos, y ese número de
# en medio va a estar más cerca de uno de los dos que ellos entre sí. Así que
# el par más cercano nunca se salta vecinos.
#
# Como toca ordenar primero, esto queda en **O(n log n)**.

# %%
import math
import random
import time
import matplotlib.pyplot as plt

def par_mas_cercano_1d(numeros):
    # ordeno la lista y comparo numeros que quedan seguidos
    if len(numeros) < 2:
        return None

    ordenados = sorted(numeros)
    mejor_distancia = float('inf')
    mejor_par = None

    for i in range(len(ordenados) - 1):
        distancia_actual = abs(ordenados[i + 1] - ordenados[i])
        if distancia_actual < mejor_distancia:
            mejor_distancia = distancia_actual
            mejor_par = (ordenados[i], ordenados[i + 1])

    return mejor_par, mejor_distancia

# %%
numeros = [3403, 4537, 9089, 9746, 7259, 1204, 6321, 8890, 2211]
par, distancia_encontrada = par_mas_cercano_1d(numeros)
print("numeros:", numeros)
print("par mas cercano:", par, " distancia:", distancia_encontrada)
# Out:
# numeros: [3403, 4537, 9089, 9746, 7259, 1204, 6321, 8890, 2211]
# par mas cercano: (8890, 9089)  distancia: 199

# %% [markdown]
# Grafico los números en una línea y marco en rojo cuáles fueron los
# ganadores.

# %%
figura, eje = plt.subplots(figsize=(9, 2))
eje.scatter(numeros, [0]*len(numeros), s=80, color="#4C72B0", zorder=3)
eje.scatter(par, [0, 0], s=140, color="red", zorder=4,
            label=f"par mas cercano (distancia={distancia_encontrada})")

for numero in numeros:
    eje.annotate(str(numero), (numero, 0), textcoords="offset points", xytext=(0, 12), ha='center', fontsize=8)

eje.set_yticks([])
eje.set_title("Puntos en 1D - el par mas cercano queda en rojo")
eje.legend(loc="upper center")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Fuerza bruta
#
# Lo más simple: comparo cada punto contra todos los demás,
# saco la distancia entre ellos y me quedo con el par que dio la distancia
# más peqeña
#
# Sirve igual para 2D, 3D, porque la distancia se calcula
# sumando las diferencias al cuadrado de cada coordenada.
#
# El problema es que con n puntos toca revisar como n²/2 parejas. Eso es
# **O(n²)** y se pone lento cuando hay muchos puntos, como voy a mostrar más
# adelante con un ejemplo grande.

# %%
def distancia(punto1, punto2):
    return math.sqrt(sum((a - b) ** 2 for a, b in zip(punto1, punto2)))


def par_mas_cercano_fuerza_bruta(puntos):
    # comparo cada punto contra todos los demas
    cantidad = len(puntos)
    mejor_distancia = float('inf')
    mejor_par = None

    for i in range(cantidad):
        for j in range(i + 1, cantidad):
            distancia_actual = distancia(puntos[i], puntos[j])
            if distancia_actual < mejor_distancia:
                mejor_distancia = distancia_actual
                mejor_par = (puntos[i], puntos[j])

    return mejor_par, mejor_distancia

# %% [markdown]
# ## 3. Divide y vencerás
#
# Fuerza bruta funciona pero es lenta. Con divide y vencerás lo que hago es
# partir el problema en pedazos chicos, resolverlos por separado y después
# juntar los resultados con cuidado.
#
# Los pasos son:
#
# 1. Ordeno los puntos por la coordenada `x`.
# 2. Los parto en dos mitades, una línea vertical imaginaria en la mitad de
#    todos los puntos.
# 3. Resuelvo cada mitad por su lado, de forma recursiva, y me quedo con la
#    mejor distancia que salió en cualquiera de las dos.
# 4. El problema es que el par más cercano de todos puede tener un punto en
#    cada mitad, o sea que cruce la línea de en medio. Para no perderme ese
#    caso, agarro solo los puntos que están cerca de esa línea (una franja
#    angosta) y los reviso aparte.
# 5. Dentro de esa franja, si ordeno los puntos por `y`, cada uno solo
#    necesita compararse con unos 7 vecinos siguientes. Esto se puede
#    demostrar con geometría, pero la idea es que no caben muchos puntos
#    amontonados en un espacio tan chico sin que ya estén más cerca de lo que
#    ya encontré.
#
# Como parto el problema a la mitad cada vez, y juntar los resultados es
# rápido, la cuenta da `T(n) = 2T(n/2) + O(n)`, que es **O(n log n)**. Ya es
# una mejora real frente a los O(n²) de fuerza bruta.

# %%
def _caso_base(puntos):
    # para grupos chiquitos (3 puntos o menos) no vale la pena complicarse
    mejor_distancia = float('inf')
    mejor_par = None
    for i in range(len(puntos)):
        for j in range(i + 1, len(puntos)):
            distancia_actual = distancia(puntos[i], puntos[j])
            if distancia_actual < mejor_distancia:
                mejor_distancia = distancia_actual
                mejor_par = (puntos[i], puntos[j])
    return mejor_par, mejor_distancia


def _revisar_franja(franja, mejor_distancia, mejor_par):
    # reviso solo los puntos que quedan cerca de la linea divisoria
    franja.sort(key=lambda punto: punto[1])
    cantidad = len(franja)

    for i in range(cantidad):
        j = i + 1
        while j < cantidad and (franja[j][1] - franja[i][1]) < mejor_distancia and (j - i) <= 7:
            distancia_actual = distancia(franja[i], franja[j])
            if distancia_actual < mejor_distancia:
                mejor_distancia = distancia_actual
                mejor_par = (franja[i], franja[j])
            j += 1

    return mejor_par, mejor_distancia


def _buscar_recursivo(puntos_por_x, puntos_por_y):
    # puntos_por_x va ordenado por x, puntos_por_y por y
    # los dejo ya ordenados para no repetir ese trabajo en cada llamada
    cantidad = len(puntos_por_x)

    if cantidad <= 3:
        return _caso_base(puntos_por_x)

    medio = cantidad // 2
    punto_medio = puntos_por_x[medio]

    izquierda_x = puntos_por_x[:medio]
    derecha_x = puntos_por_x[medio:]

    ids_izquierda = set(map(id, izquierda_x))
    izquierda_y = [punto for punto in puntos_por_y if id(punto) in ids_izquierda]
    derecha_y = [punto for punto in puntos_por_y if id(punto) not in ids_izquierda]

    par_izquierda, distancia_izquierda = _buscar_recursivo(izquierda_x, izquierda_y)
    par_derecha, distancia_derecha = _buscar_recursivo(derecha_x, derecha_y)

    if distancia_izquierda <= distancia_derecha:
        mejor_par, mejor_distancia = par_izquierda, distancia_izquierda
    else:
        mejor_par, mejor_distancia = par_derecha, distancia_derecha

    franja = [punto for punto in puntos_por_y if abs(punto[0] - punto_medio[0]) < mejor_distancia]
    mejor_par, mejor_distancia = _revisar_franja(franja, mejor_distancia, mejor_par)

    return mejor_par, mejor_distancia


def par_mas_cercano_divide_venceras_2d(puntos):
    if len(puntos) < 2:
        return None

    puntos_por_x = sorted(puntos, key=lambda punto: punto[0])
    puntos_por_y = sorted(puntos, key=lambda punto: punto[1])
    return _buscar_recursivo(puntos_por_x, puntos_por_y)

# %% [markdown]
# ## 4. Probando en 2D
#
# Uso los puntos de ejemplo de la guía y corro los dos métodos para revisar
# que den el mismo resultado.

# %%
puntos_2d = [(1122, 6175), (135, 4076), (7296, 2741),
             (500, 4100), (7300, 2750), (3000, 3000),
             (1200, 6200), (9999, 1)]

par_bruto, distancia_bruta = par_mas_cercano_fuerza_bruta(puntos_2d)
print("fuerza bruta ->", par_bruto, " distancia:", round(distancia_bruta, 4))

par_dyv, distancia_dyv = par_mas_cercano_divide_venceras_2d(puntos_2d)
print("divide y venceras ->", par_dyv, " distancia:", round(distancia_dyv, 4))

assert round(distancia_bruta, 6) == round(distancia_dyv, 6)
print("dan lo mismo, todo bien")
# Out:
# fuerza bruta -> ((7296, 2741), (7300, 2750))  distancia: 9.8489
# divide y venceras -> ((7296, 2741), (7300, 2750))  distancia: 9.8489
# dan lo mismo, todo bien

# %% [markdown]
# Grafico todos los puntos en el plano y marco en rojo el par que
# ganó, conectado con una línea, para comprobar a ojo que sí son los más
# cercanos.

# %%
equis = [punto[0] for punto in puntos_2d]
yes = [punto[1] for punto in puntos_2d]

figura, eje = plt.subplots(figsize=(7, 6))
eje.scatter(equis, yes, s=90, color="#4C72B0", zorder=3, label="puntos")

punto_a, punto_b = par_dyv
eje.plot([punto_a[0], punto_b[0]], [punto_a[1], punto_b[1]], color="red", linewidth=2, zorder=4)
eje.scatter([punto_a[0], punto_b[0]], [punto_a[1], punto_b[1]], s=140, color="red", zorder=5,
            label=f"par más cercano (distancia={distancia_dyv:.2f})")

for x, y in puntos_2d:
    eje.annotate(f"({x},{y})", (x, y), textcoords="offset points", xytext=(6, 6), fontsize=8)

eje.set_title("Puntos en 2D y el par más cercano")
eje.set_xlabel("x")
eje.set_ylabel("y")
eje.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Ahora en 3D
#
# La lógica es casi la misma que en 2D, solo que ahora cada punto tiene una
# coordenada más (`x, y, z`) y la distancia se calcula con las tres.
#
# La diferencia está en la franja de en medio: en 2D bastaba revisar unos 7
# vecinos, pero en 3D hay más espacio para que quepan puntos cerca sin pasarse
# de la distancia mínima. Por eso reviso más vecinos, uso 40, para no dejar
# pasar por error el par correcto.
#
# Sigue siendo **O(n log n)** porque la forma de la recursión es la misma.

# %%
def _revisar_franja_3d(franja, mejor_distancia, mejor_par):
    franja.sort(key=lambda punto: punto[1])
    cantidad = len(franja)
    limite_vecinos = 40  # en 3D dejo mas margen que en 2D

    for i in range(cantidad):
        j = i + 1
        while j < cantidad and (franja[j][1] - franja[i][1]) < mejor_distancia and (j - i) <= limite_vecinos:
            distancia_actual = distancia(franja[i], franja[j])
            if distancia_actual < mejor_distancia:
                mejor_distancia = distancia_actual
                mejor_par = (franja[i], franja[j])
            j += 1

    return mejor_par, mejor_distancia


def _buscar_recursivo_3d(puntos_por_x, puntos_por_y):
    cantidad = len(puntos_por_x)

    if cantidad <= 3:
        return _caso_base(puntos_por_x)

    medio = cantidad // 2
    punto_medio = puntos_por_x[medio]

    izquierda_x = puntos_por_x[:medio]
    derecha_x = puntos_por_x[medio:]

    ids_izquierda = set(map(id, izquierda_x))
    izquierda_y = [punto for punto in puntos_por_y if id(punto) in ids_izquierda]
    derecha_y = [punto for punto in puntos_por_y if id(punto) not in ids_izquierda]

    par_izquierda, distancia_izquierda = _buscar_recursivo_3d(izquierda_x, izquierda_y)
    par_derecha, distancia_derecha = _buscar_recursivo_3d(derecha_x, derecha_y)

    if distancia_izquierda <= distancia_derecha:
        mejor_par, mejor_distancia = par_izquierda, distancia_izquierda
    else:
        mejor_par, mejor_distancia = par_derecha, distancia_derecha

    franja = [punto for punto in puntos_por_y if abs(punto[0] - punto_medio[0]) < mejor_distancia]
    mejor_par, mejor_distancia = _revisar_franja_3d(franja, mejor_distancia, mejor_par)

    return mejor_par, mejor_distancia


def par_mas_cercano_divide_venceras_3d(puntos):
    if len(puntos) < 2:
        return None

    puntos_por_x = sorted(puntos, key=lambda punto: punto[0])
    puntos_por_y = sorted(puntos, key=lambda punto: punto[1])
    return _buscar_recursivo_3d(puntos_por_x, puntos_por_y)

# %%
puntos_3d = [(1122, 6175, 300), (135, 4076, 900), (7296, 2741, 120),
             (500, 4100, 890), (7300, 2750, 125), (3000, 3000, 3000),
             (1200, 6200, 305), (9999, 1, 50)]

par_bruto_3d, distancia_bruta_3d = par_mas_cercano_fuerza_bruta(puntos_3d)
print("fuerza bruta ->", par_bruto_3d, " distancia:", round(distancia_bruta_3d, 4))

par_dyv_3d, distancia_dyv_3d = par_mas_cercano_divide_venceras_3d(puntos_3d)
print("divide y venceras ->", par_dyv_3d, " distancia:", round(distancia_dyv_3d, 4))

assert round(distancia_bruta_3d, 6) == round(distancia_dyv_3d, 6)
print("dan lo mismo, todo bien")
# Out:
# fuerza bruta -> ((7296, 2741, 120), (7300, 2750, 125))  distancia: 11.0454
# divide y venceras -> ((7296, 2741, 120), (7300, 2750, 125))  distancia: 11.0454
# dan lo mismo, todo bien

# %% [markdown]
# Y la gráfica en 3D, mismo estilo que la de 2D.

# %%
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 (hace falta para el proyeccion 3d)

figura = plt.figure(figsize=(8, 7))
eje = figura.add_subplot(111, projection='3d')

equis3 = [punto[0] for punto in puntos_3d]
yes3 = [punto[1] for punto in puntos_3d]
zetas3 = [punto[2] for punto in puntos_3d]

eje.scatter(equis3, yes3, zetas3, s=80, color="#4C72B0", label="puntos")

punto_a, punto_b = par_dyv_3d
eje.plot([punto_a[0], punto_b[0]], [punto_a[1], punto_b[1]], [punto_a[2], punto_b[2]], color="red", linewidth=2)
eje.scatter([punto_a[0], punto_b[0]], [punto_a[1], punto_b[1]], [punto_a[2], punto_b[2]], s=140, color="red",
            label=f"par m´ss cercano (distancia={distancia_dyv_3d:.2f})")

eje.set_title("Puntos en 3D y el par más cercano")
eje.set_xlabel("x")
eje.set_ylabel("y")
eje.set_zlabel("z")
eje.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. ¿De verdad vale la pena divide y vencerás?
#
# Para no quedarme solo con la teoría, genero 3000 puntos al azar y corro los
# dos métodos midiendo cuánto se demoran. Los dos deben dar la misma
# distancia mínima, pero uno se va a demorar bastante más que el otro.

# %%
random.seed(42)
puntos_al_azar = [(random.uniform(0, 100000), random.uniform(0, 100000))
                   for _ in range(3000)]

inicio = time.time()
_, distancia_bruta_grande = par_mas_cercano_fuerza_bruta(puntos_al_azar)
tiempo_bruto = time.time() - inicio

inicio = time.time()
_, distancia_dyv_grande = par_mas_cercano_divide_venceras_2d(puntos_al_azar)
tiempo_dyv = time.time() - inicio

print(f"con {len(puntos_al_azar)} puntos:")
print(f"  fuerza bruta      -> distancia {distancia_bruta_grande:.4f}, se demoro {tiempo_bruto:.4f}s")
print(f"  divide y venceras -> distancia {distancia_dyv_grande:.4f}, se demoro {tiempo_dyv:.4f}s")
# Out:
# con 3000 puntos:
#   fuerza bruta      -> distancia 21.7985, se demoro 10.0688s
#   divide y venceras -> distancia 21.7985, se demoro 0.0382s

# %% [markdown]
# Y una gráfica de barras comparando los dos tiempos, para que quede
# bien claro.

# %%
figura, eje = plt.subplots(figsize=(6, 5))
metodos = ["Fuerza bruta\nO(n^2)", "Divide y Venceras\nO(n log n)"]
tiempos = [tiempo_bruto, tiempo_dyv]
colores = ["#C44E52", "#55A868"]

barras = eje.bar(metodos, tiempos, color=colores)
eje.set_ylabel("segundos")
eje.set_title(f"Tiempo de ejecucion con {len(puntos_al_azar)} puntos")

for barra, tiempo in zip(barras, tiempos):
    eje.annotate(f"{tiempo:.3f}s", (barra.get_x() + barra.get_width()/2, barra.get_height()),
                 textcoords="offset points", xytext=(0, 5), ha='center')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Para cerrar
#
# | Método | Qué tan rápido es | Por qué |
# |---|---|---|
# | 1D (ordenar y ver vecinos) | O(n log n) | lo único que demora es ordenar |
# | Fuerza bruta (2D/3D) | O(n²) | comparo todo contra todo, por eso se pone lento |
# | Divide y vencerás 2D | O(n log n) | parto el problema a la mitad y juntar los resultados es rápido (7 vecinos por punto en la franja) |
# | Divide y vencerás 3D | O(n log n) | mismo truco, solo que en la franja reviso más vecinos por el espacio extra |
#
# La gráfica de tiempos deja claro por qué en la guía preguntan si se puede
# mejorar la fuerza bruta: sí se puede, y bastante.
